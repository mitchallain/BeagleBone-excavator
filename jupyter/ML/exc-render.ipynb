# %% [markdown]
# # Excavator Renderer
#
# The objective of this notebook is to render the excavator in a 3D figure given the actuator displacements.

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
from trajectories import exc
import trajectories
import learning
import numpy as np
import math

# %%
matplotlib.style.use('mitch-exp')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

trajectories.draw_exc(ax, [8.9, 10.16, 2.5, 0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a1, a2, a3, a4
# Out:
# (3.7, 48.2, 25.3, 11.5)

# %%
reload(trajectories)
# Out:
# <module 'trajectories' from 'trajectories.py'>

# %% [markdown]
# # Test Excavator Visualization
#
# Test the draw_exc() func in trajectories by making a GIF of a trial

# %%
ls trial_data/
# Out:
# manual_mitch_1102_1814.csv

# %%
path = 'trial_data/' + 'manual_mitch_1102_1814.csv'

pos, rate_sm = learning.compute_rate(path)
rate_sm = np.nan_to_num(rate_sm)
pos.shape
# Out:
# (5, 1712)

# %%
pos[1:,1].shape
# Out:
# (4,)

# %% [markdown]
# ### Animate the excavator demonstration
#
# Use  `matplotlib.animation.FuncAnimation`  for the animation and 'imagemagick' to write a GIF.

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

def update(i):
    plt.cla()
    trajectories.draw_exc(ax, pos[1:, i*5])
    

anim = FuncAnimation(fig, update, frames=np.arange(0, 3), interval=200)
# anim.save('exc.gif', dpi=80, writer='imagemagick')
# Out:
# <img src="data:image/png;base64,..." width="600">
